# %% [markdown]
# # 00 — My Working Directory
#
# Before we do anything spatial, we must know:
#
# - What is the current working directory?
# - Does the `data/` folder exist?
# - If the data doesn't exist, then stop nicely (don't crash).
# - We can fix it this time by creating and copying whats needed to your local folder.

# %%
from pathlib import Path

## put a link to pathlib

# Get path of the current working directory
cwd = Path.cwd()
print("Current Working Directory:")
print(cwd)

# add data folder to end of path
data_path = cwd / "data"
print("\nLooking for data folder at:")
print(data_path)

# check to see if that path exists
exists = data_path.exists()
print("\nDoes data folder exist?")
print(exists)

## Its not going to exist, so you need to use the `parent` attribute to back up a directory to find the data folder
## which is even with the _micro_lessons folder.

assert exists, (
    f"\n❌ ERROR: 'data/' folder not found at:\n{data_path}\n"
    "Check your working directory or update the path to find your file."
)

print("\n✅ Environment looks correct.")
# Out:
# Current Working Directory:
# /content
#
# Looking for data folder at:
# /content/data
#
# Does data folder exist?
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_2220/1420406098.py in <cell line: 0>()
#      21 ## which is even with the _micro_lessons folder.
#      22
# ---> 23 assert exists, (
#      24     f"\n❌ ERROR: 'data/' folder not found at:\n{data_path}\n"
#      25     "Check your working directory or update the path to find your file."
#
# AssertionError:
# ❌ ERROR: 'data/' folder not found at:
# /content/data
# Check your working directory or update the path to find your file.

# %%
from pathlib import Path

cwd = Path.cwd()

# go up one level first
data_path = cwd.parent / "data"

print("Trying:", data_path)
print("Exists?", data_path.exists())
# Out:
# Trying: /data
# Exists? False

# %% [markdown]
# ## Next
#
# - You can't always make copies of files locally just to make coding easier. In the next lesson, we will work on opening files that exist elsewhere.
