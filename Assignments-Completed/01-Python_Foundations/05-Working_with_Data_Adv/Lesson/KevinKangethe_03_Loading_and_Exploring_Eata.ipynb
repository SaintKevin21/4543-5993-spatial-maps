# %% [markdown]
# # 📂 Notebook 03: Loading and Exploring Data
#
# Welcome to the real world — where data lives in messy CSVs and your job is to make sense of it.
#
# In this notebook, you’ll:
# - Load a CSV file using `pd.read_csv()`
# - Use `.head()`, `.tail()`, `.info()`, and `.describe()` to explore your data
# - Identify potential issues (missing values, bad types, oddball rows)
#
# Let’s get our hands dirty.
# ---

# %%
import pandas as pd

# %% [markdown]
# ## 📥 Load a CSV
#
# Replace the filename below with a real CSV path or URL. For testing, use built-in seaborn datasets.

# %%
# Example with seaborn's Titanic dataset
import seaborn as sns
df = sns.load_dataset("./data/titanic")
df.head()
# Out:
# Cannot decode configuration file PosixPath('/Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/matplotlib/mpl-data/stylelib/.__classic_test_patch.mplstyle') as utf-8.
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Example with seaborn's Titanic dataset
# ----> 2 import seaborn as sns
#       3 df = sns.load_dataset("./data/titanic")
#       4 df.head()
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/seaborn/__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/seaborn/rcmod.py:5
#       3 import matplotlib as mpl
#       4 from cycler import cycler
# ----> 5 from . import palettes
#       8 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#       9            "axes_style", "set_style", "plotting_context", "set_context",
#      10            "set_palette"]
#      13 _style_keys = [
#      14
#      15     "axes.facecolor",
#    (...)     50
#      51 ]
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/seaborn/palettes.py:9
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11 from ._compat import get_colormap
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/seaborn/utils.py:14
#      12 import matplotlib as mpl
#      13 from matplotlib.colors import to_rgb
# ---> 14 import matplotlib.pyplot as plt
#      15 from matplotlib.cbook import normalize_kwargs
#      17 from seaborn._core.typing import deprecated
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:62
#      60 from matplotlib import get_backend as get_backend, rcParams as rcParams
#      61 from matplotlib import cm as cm  # noqa: F401
# ---> 62 from matplotlib import style as style  # noqa: F401
#      63 from matplotlib import _pylab_helpers
#      64 from matplotlib import interactive  # noqa: F401
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/matplotlib/style/__init__.py:1
# ----> 1 from .core import available, context, library, reload_library, use
#       4 __all__ = ["available", "context", "library", "reload_library", "use"]
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:225
#     220     return main_dict
#     223 # Load style library
#     224 # ==================
# --> 225 _base_library = read_style_directory(BASE_LIBRARY_PATH)
#     226 library = {}
#     227 available = []
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:203, in read_style_directory(style_dir)
#     201 for path in Path(style_dir).glob(f"*.{STYLE_EXTENSION}"):
#     202     with warnings.catch_warnings(record=True) as warns:
# --> 203         styles[path.stem] = _rc_params_in_file(path)
#     204     for w in warns:
#     205         _log.warning('In %s: %s', path, w.message)
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:908, in _rc_params_in_file(fname, transform, fail_on_error)
#     906 with _open_file_or_url(fname) as fd:
#     907     try:
# --> 908         for line_no, line in enumerate(fd, 1):
#     909             line = transform(line)
#     910             strippedline = cbook._strip_comment(line)
#
# File <frozen codecs>:325, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte

# %% [markdown]
# ## 📊 Peek at the Data

# %%
# First and last few rows
print("First 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())

# %% [markdown]
# ## 🧠 Understand Structure

# %%
# Dimensions and columns
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())

# %% [markdown]
# ## 🧼 Data Types & Missing Values

# %%
# Data types and null counts
print("\nInfo:")
df.info()

# How many missing values per column?
print("\nMissing values per column:")
print(df.isnull().sum())

# %% [markdown]
# ## 📈 Summary Statistics

# %%
df.describe(include="all")

# %% [markdown]
# ## ✏️ Renaming Columns (Optional but fun)

# %%
# Rename 'sex' to 'gender' for clarity
df.rename(columns={"sex": "gender"}, inplace=True)
df.head(2)

# %% [markdown]
# ---
# ## 🔍 Your Turn
#
# 1. Load a dataset of your choice (`pd.read_csv()` or `sns.load_dataset()`)
# 2. Print the first and last 5 rows.
# 3. Show `.info()` and `.describe()` results.
# 4. Print the column names. Rename one of them.
#
# 🎯 **Bonus:** What percentage of rows have *any* missing values?
#
# ```python
# # HINT:
# df.isnull().any(axis=1).mean() * 100  # percent of rows with any NaNs
# ```

# %%
# Your exploratory code playground!

# %%
#1
import pandas as pd

# Load dataset from URL (safe and reliable)
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv")

# %%
#2
print("First 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())
# Out:
# First 5 rows:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Last 5 rows:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print("\nShape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nDataFrame Info:")
df.info()

print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Shape: (891, 15)
#
# Columns: ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB
#
# Missing values per column:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
print("\nSummary Statistics:")
print(df.describe(include="all"))
df.rename(columns={"sex": "gender"}, inplace=True)

print("\nAfter Renaming Column:")
print(df.head(2))
# Out:
# Summary Statistics:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   891.000000      889    891  891        891  203          889   891
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      644    491  537        537   59          644   549
# mean     32.204208      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    891
# unique     2
# top     True
# freq     537
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
#
# After Renaming Column:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %% [markdown]
# ---
# ## 🎓 Why This Matters
#
# Every data science project begins here — importing and inspecting data. If your data is a mess (spoiler: it always is), you need to know how to check it, clean it, and prep it.
#
# Next up: slicing and dicing — using `.loc[]`, `.iloc[]`, and boolean masks to select what you want and ignore what you don't.
